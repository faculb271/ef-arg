# %% [markdown]
# <a href="https://colab.research.google.com/github/faculb271/Finanzas/blob/main/ICC_Santiago_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/query ICC full.xlsx', sheet_name='PYTHON')
df.set_index('Mes', inplace=True)
series_economicas = df.drop(columns=['Provincia'])

series_economicas.head() #Visualizo la data
# Out:
#             Pat_0km    Motos   Transf    Copart*  Gasoil  Nafta   Gas_ind  \
# Mes
# 2007-01-01  325.728  407.781  609.867  80308.542     NaN    NaN   914.964
# 2007-02-01  332.187  441.586  512.494  78100.733     NaN    NaN   897.601
# 2007-03-01  341.374  420.207  597.528  79257.424     NaN    NaN  1091.932
# 2007-04-01  320.435  461.796  569.954  75944.916     NaN    NaN  1001.332
# 2007-05-01  372.610  413.613  513.879  82721.935     NaN    NaN   968.710
#
#             Ene_Ind  Super_ajIPC     Empleo      Masal_aj    Cemento  \
# Mes
# 2007-01-01      NaN          NaN  77194.515  3.377082e+10  10747.997
# 2007-02-01      NaN          NaN  76666.212  3.368684e+10  13717.166
# 2007-03-01      NaN          NaN  78110.414  3.418619e+10  12822.753
# 2007-04-01      NaN          NaN  77674.095  3.325729e+10  13371.691
# 2007-05-01      NaN          NaN  78203.860  1.524004e+10  12461.769
#
#                   EMAE  ICC-SDE (Base Ene 07=100)
# Mes
# ...

# %% [markdown]
# # Turning points

# %%
for columna in series_economicas.columns:
    data = series_economicas[columna]

    # Calcular máximos y mínimos locales
    maxima = argrelextrema(data.values, np.greater, order=5)[0]
    minima = argrelextrema(data.values, np.less, order=5)[0]

    # Visualización
    plt.figure(figsize=(10, 6))
    plt.plot(data, label='Serie Original')
    plt.plot(data.iloc[maxima], 'ro', label='Máximos Locales')
    plt.plot(data.iloc[minima], 'go', label='Mínimos Locales')
    plt.legend()
    plt.title(f'Identificación de Máximos y Mínimos Locales para {columna}')
    plt.show()
